# %% [markdown]
# ### 상대모멘텀
#
# - s = 종목, p = 산다, r = 판다
# - return 값이 음수가 나오는 경우는 종목들이 다 -이고, 그 중에서 그나마 나은걸 산 것
#
# - 과거의 데이터에 첫 날과 마지막 날의 종가를 비교해서 수익률이 높은 종목을 산다.
# - 샀던 종목이 높은 종목이면 그대로 놔두고, 다른 종목이면 자동으로 팔고 다른 종목을 산다.

# %%
import os
import pandas as pd
import numpy as np
import datetime
import glob

# %%
# 파일 목록 불러오기

files = glob.glob('./csv/*.csv')           # '*' 표시는 해당 파일에서 모두 불러온다는 뜻

files
# Out:
# ['./csv/AMZN.csv', './csv/BND.csv', './csv/AAPL.csv']

# %%
# 'month_last_df'라는 빈 데이터프레임 지정(컬럼 이름만 지정해둠)

month_last_df = pd.DataFrame(columns = ['Date', 'CODE', '1M_RET'])

month_last_df
# Out:
# Empty DataFrame
# Columns: [Date, CODE, 1M_RET]
# Index: []

# %%
# 종목 데이터프레임 생성

stock_df = pd.DataFrame(columns = ['Date', 'CODE', 'Adj Close'])

# %%
for file in files :

    if os.path.isdir(file) :

        print('%s <DIR>' %file)
    
    else :

        folder, name = os.path.split(file)
        head, tail = os.path.splitext(name)

        print(folder, name, head, tail)

        read_df = pd.read_csv(file)

        print(read_df.head(1))
# Out:
# ./csv AMZN.csv AMZN .csv
#          Date    Open  High       Low     Close  Adj Close    Volume
# 0  1997-05-15  2.4375   2.5  1.927083  1.958333   1.958333  72156000
# ./csv BND.csv BND .csv
#          Date   Open       High   Low      Close  Adj Close  Volume
# 0  2007-04-10  75.07  75.260002  75.0  75.239998  51.523693   35000
# ./csv AAPL.csv AAPL .csv
#          Date      Open      High       Low     Close  Adj Close       Volume
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.410525  117258400.0

# %%
def data_preprocessing(sample, ticker, base_date) :

    # sample = AAPL.csv를 읽은 후 데이터프레임화
    # ticker = AAPL
    # base_date = '2010-01-01'
    
    sample['CODE'] = ticker     # 종목코드 추가

    sample = sample[sample['Date'] >= base_date][ ['Date', 'CODE', 'Adj Close'] ]

    # 'inplace = True'는 기준이 되는 데이터프레임을 수정
    # 'drop = True'는 기존 인덱스를 삭제
    sample.reset_index(inplace = True, drop = True)

    # 기준년월
    sample['STD-YM'] = sample['Date'].map(lambda x : datetime.datetime.strptime(x, '%Y-%m-%d').strftime('%Y-%m'))
    # 수익률
    sample['1M_RET'] = 0.0

    # 기준년월의 중복 데이터를 삭제한 리스트를 출력
    ym_keys = list(sample['STD-YM'].unique())

    return sample, ym_keys

# %%
df = pd.read_csv('./csv/AAPL.csv')

price_df, ym_keys = data_preprocessing(df, 'AAPL', '2010-01-01')

print(price_df)
print(ym_keys)
# Out:
#             Date  CODE   Adj Close   STD-YM  1M_RET
# 0     2010-01-04  AAPL   26.782711  2010-01     0.0
# 1     2010-01-05  AAPL   26.829010  2010-01     0.0
# 2     2010-01-06  AAPL   26.402260  2010-01     0.0
# 3     2010-01-07  AAPL   26.353460  2010-01     0.0
# 4     2010-01-08  AAPL   26.528664  2010-01     0.0
# ...          ...   ...         ...      ...     ...
# 2379  2019-06-18  AAPL  198.449997  2019-06     0.0
# 2380  2019-06-19  AAPL  197.869995  2019-06     0.0
# 2381  2019-06-20  AAPL  199.460007  2019-06     0.0
# 2382  2019-06-21  AAPL  198.779999  2019-06     0.0
# 2383  2019-06-24  AAPL  199.169998  2019-06     0.0
#
# [2384 rows x 5 columns]
# ['2010-01', '2010-02', '2010-03', '2010-04', '2010-05', '2010-06', '2010-07', '2010-08', '2010-09', '2010-10', '2010-11', '2010-12', '2011-01', '2011-02', '2011-03', '2011-04', '2011-05', '2011-06', '2011-07', '2011-08', '2011-09', '2011-10', '2011-11', '2011-12', '2012-01', '2012-02', '2012-03', '2012-04', '2012-05', '2012-06', '2012-07', '2012-08', '2012-09', '2012-10', '2012-11', '2012-12', '2013-01', '2013-02', '2013-03', '2013-04', '2013-05', '2013-06', '2013-07', '2013-08', '2013-09', '2013-10', '2013-11', '2013-12', '2014-01', '2014-02', '2014-03', '2014-04', '2014-05', '2014-06', '2014-07', '2014-08', '2014-09', '2014-10', '2014-11', '2014-12', '2015-01', '2015-02', '2015-03', '2015-04', '2015-05', '2015-06', '2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12', '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06', '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12', '2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06', '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12', '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12', '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06']

# %%
def create_trade_book(sample, sample_codes) :

    book = pd.DataFrame()
    book = sample[sample_codes]
    book['STD-YM'] = book.index.map(lambda x : datetime.datetime.strptime(x, '%Y-%m-%d').strftime('%Y-%m'))

    for i in sample_codes :
        
        book['p ' + i] = ''
        book['r ' + i] = ''

    return book

# %%
# trading 함수 생성

def tradings(book, s_codes) :

    std_ym = ''
    buy_phase = ''

    for i in s_codes :

        print(i)

        # 종목코드의 인덱스를 기준으로 반복
        for j in book.index :

            if book.loc[j, 'p ' + i] == '' and book.shift(1).loc[j, 'p ' + i] == 'ready ' + i :

                std_ym = book.loc[j, 'STD-YM']
                buy_phase = True


            if book.loc[j, 'p ' + i] == '' and book.loc[j, 'STD-YM'] == std_ym and buy_phase == True :

                book.loc[j, 'p ' + i] = 'buy ' + i


            if book.loc[j, 'p ' + i] == '' :        # 반복문 빠져나오기

                std_ym = None
                buy_phase = False            

    return book

# %%
def multi_returns(book, s_codes) :

    rtn = 1.0
    num = len(s_codes)
    buy_dict = {}
    sell_dict = {}

    for i in book.index :

        for s in s_codes :        # s는 종목 ex) AAPL, AMZN..

            if book.loc[i, 'p ' + s] == 'buy ' + s and \
            book.shift(1).loc[i, 'p ' + s] == 'ready ' + s and \
            book.shift(2).loc[i, 'p ' + s] == '' :          # 중복매수 방지

                buy_dict[s] = book.loc[i, s]

                print('진입일: ', i, '종목코드: ', s, 'long 진입 가격: ', buy_dict[s])

            elif book.loc[i, 'p ' + s] == '' and \
                book.shift(1).loc[i, 'p ' + s] == 'buy ' + s :

                sell_dict[s] = book.loc[i, s]

                # 손익계산
                rtn = (sell_dict[s] / buy_dict[s]) - 1
                book.loc[i, 'r ' + s] = rtn

                print('개별 청산일: ', i, '종목코드: ', s, 'long 진입 가격: ', \
                    buy_dict[s], 'long 청산 가격: ', sell_dict[s], 'return: ', round(rtn * 100, 2))


            if book.loc[i, 'p ' + s] == '' :

                buy_dict[s] = 0.0
                sell_dict[s] = 0.0

    acc_rtn = 1.0

    for i in book.index :

        rtn = 0.0
        count = 0

        for s in s_codes :

            if book.loc[i, 'p ' + s] == '' and \
                book.shift(1).loc[i, 'p ' + s] == 'buy ' + s :

                count += 1
                rtn += book.loc[i, 'r ' + s]


        if (rtn != 0.0) and (count != 0) :

            acc_rtn *= (rtn / count) + 1

            print('누적 청산일: ', i, '청산 종목 수: ', count, \
                '청산 수익률: ', round((rtn / count), 4), '누적 수익률: ', round(acc_rtn, 4))

            book.loc[i, 'acc_rtn'] = acc_rtn

    print('누적 수익률: ', round(acc_rtn, 4))

# %%
for file in files :
    
    if os.path.isdir(file) :

        print('%s <DIR>' %file)
    
    else :

        # file = './csv\AAPL.csv'
        # split() → folder = './csv', name = 'AAPL.csv'
        # splitext() → head = 'AAPL', tail = '.csv'

        folder, name = os.path.split(file)
        head, tail = os.path.splitext(name)

        #print(folder, name, head, tail)

        read_df = pd.read_csv(file, encoding = 'CP949')

        #print(read_df.head(1))
        
        price_df, ym_keys = data_preprocessing(read_df, head, '2010-01-01')

        stock_df = pd.concat([stock_df, price_df[['Date', 'CODE', 'Adj Close']]])

        for ym in ym_keys :

            # 기준년월의 마지막 종가 / 기준년월의 첫 종가를 나누는 기준

            # m_ret이라는 변수를 만들어서
            # ym = '2020-01'

            # [price_df['STD-YM'] == '2020-01] → 'STD-YM'의 값이 2020-01이면 T, 아니면 F
            # price_df.loc[price_df[price_df['STD-YM'] == '2020-01'] → [] 안의 조건식이 T 출력, F 미출력
            # price_df.loc[price_df[price_df['STD-YM'] == '2020-01'].index[-1] → 'STD-YM'의 값이 2020-01인 값들 중에 가장 마지막에 있는 인덱스 값
            
            # price_df.loc[price_df[price_df['STD-YM'] == '2020-01'].index[-1], 'Adj Close']
            # price_df.loc[index, col] → index = price_df[price_df['STD-YM'] == '2020-01].index[-1], col = Adj Close

            # 결과적으로 price_df에 있는 STD-YM 칼럼의 값이
            # 2020-01인 행들 중에 가장 마지막에 있는 행의 Adj Close 값

            # 기준년월의 제일 마지막에 있는 값에 인덱스
            m_ret = price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], 'Adj Close'] \
                    / price_df.loc[price_df[price_df['STD-YM'] == ym].index[0], 'Adj Close']

            price_df.loc[price_df['STD-YM'] == ym, ['1M_RET']] = m_ret

            month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# Out:
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# ...
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2106956523.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   month_last_df = month_last_df.append(price_df.loc[price_df[price_df['STD-YM'] == ym].index[-1], ['Date', 'CODE', '1M_RET']])

# %%
month_last_df.head(10)
# Out:
#            Date  CODE    1M_RET
# 18   2010-01-29  AMZN  0.936595
# 37   2010-02-26  AMZN  0.996046
# 60   2010-03-31  AMZN  1.090172
# 81   2010-04-30  AMZN  1.040134
# 101  2010-05-28  AMZN  0.912503
# 123  2010-06-30  AMZN  0.886563
# 144  2010-07-30  AMZN  1.062455
# 166  2010-08-31  AMZN  1.039644
# 187  2010-09-30  AMZN  1.185448
# 208  2010-10-29  AMZN  1.074946

# %%
month_ret_df = month_last_df.pivot('Date', 'CODE', '1M_RET')

month_ret_df
# Out:
# CODE            AAPL      AMZN       BND
# Date
# 2010-01-29  0.897435  0.936595  1.011692
# 2010-02-26  1.050789  0.996046  1.003909
# 2010-03-31  1.124456  1.090172  0.996728
# 2010-04-30  1.106454  1.040134  1.011023
# 2010-05-28  0.964445  0.912503  1.011821
# ...              ...       ...       ...
# 2019-02-28  1.044274  1.008363  1.001883
# 2019-03-29  1.085615  1.065214  1.022547
# 2019-04-30  1.049310  1.061917  1.003719
# 2019-05-31  0.834810  0.928617  1.018200
# 2019-06-24  1.149279  1.127173  1.007778
#
# [114 rows x 3 columns]

# %%
# 투자종목 선택할 rank

month_ret_df = month_ret_df.rank(axis = 1, ascending = False, method = 'max', pct = True)

# %%
# 상위 40%에 드는 종목을 체크

month_ret_df = month_ret_df.where(month_ret_df < 0.4, np.nan).fillna(0)

month_ret_df[month_ret_df != 0] = 1

month_ret_df
# Out:
# CODE        AAPL  AMZN  BND
# Date
# 2010-01-29   0.0   0.0  1.0
# 2010-02-26   1.0   0.0  0.0
# 2010-03-31   1.0   0.0  0.0
# 2010-04-30   1.0   0.0  0.0
# 2010-05-28   0.0   0.0  1.0
# ...          ...   ...  ...
# 2019-02-28   1.0   0.0  0.0
# 2019-03-29   1.0   0.0  0.0
# 2019-04-30   0.0   1.0  0.0
# 2019-05-31   0.0   0.0  1.0
# 2019-06-24   1.0   0.0  0.0
#
# [114 rows x 3 columns]

# %%
stock_list = list(stock_df['CODE'].unique())

stock_list
# Out:
# ['AMZN', 'BND', 'AAPL']

# %%
# 비어있는 딕셔너리 형태 데이터

sig_dict = dict()

for date in month_ret_df.index :

    ticker_list = list(month_ret_df.loc[date, month_ret_df.loc[date, :] >= 1.0].index)

    # 날짜별로 종목코드 저장
    sig_dict[date] = ticker_list

stock_c_matrix = stock_df.pivot('Date', 'CODE', 'Adj Close')

book = create_trade_book(stock_c_matrix, stock_list)

book.head()
# Out:
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/1349359197.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book['STD-YM'] = book.index.map(lambda x : datetime.datetime.strptime(x, '%Y-%m-%d').strftime('%Y-%m'))
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/1349359197.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book['p ' + i] = ''
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/1349359197.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book['r ' + i] = ''
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/1349359197.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book['p ' + i] = ''
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/1349359197.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book['r ' + i] = ''
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/1349359197.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book['p ' + i] = ''
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/1349359197.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book['r ' + i] = ''
# CODE              AMZN        BND       AAPL   STD-YM p AMZN r AMZN p BND  \
# Date
# 2010-01-04  133.899994  60.611969  26.782711  2010-01
# 2010-01-05  134.690002  60.789135  26.829010  2010-01
# 2010-01-06  132.250000  60.766037  26.402260  2010-01
# 2010-01-07  130.000000  60.719822  26.353460  2010-01
# 2010-01-08  133.520004  60.781410  26.528664  2010-01
#
# CODE       r BND p AAPL r AAPL
# Date
# 2010-01-04
# 2010-01-05
# 2010-01-06
# 2010-01-07
# 2010-01-08

# %%
# 반복문이 처음 시작하는 경우
# date = 2010-01-29
# values = ['BND']
# stock = 'BND'(리스트에서 빠져나온 str 형태의 데이터로 바뀜)
# bool.loc['2010-01-29', 'p BND'] = 'readyBND'

for date, values in sig_dict.items() :

    for stock in values :

        book.loc[date, 'p ' + stock] = 'ready ' + stock 

book.value_counts('p AAPL')
# Out:
# p AAPL
#               2345
# ready AAPL      39
# dtype: int64

# %%
stock_list
# Out:
# ['AMZN', 'BND', 'AAPL']

# %%
book = tradings(book, stock_list)
# Out:
# AMZN
# BND
# AAPL

# %%
multi_returns(book, stock_list)
# Out:
# 진입일:  2010-02-01 종목코드:  BND long 진입 가격:  61.280487
# 개별 청산일:  2010-03-01 종목코드:  BND long 진입 가격:  61.280487 long 청산 가격:  61.585163 return:  0.5
# 진입일:  2010-03-01 종목코드:  AAPL long 진입 가격:  26.154476
# 진입일:  2010-06-01 종목코드:  BND long 진입 가격:  62.79007
# 개별 청산일:  2010-06-01 종목코드:  AAPL long 진입 가격:  26.154476 long 청산 가격:  32.642082 return:  24.8
# 진입일:  2010-08-02 종목코드:  AMZN long 진입 가격:  120.07
# 개별 청산일:  2010-08-02 종목코드:  BND long 진입 가격:  62.79007 long 청산 가격:  64.18457 return:  2.22
# 개별 청산일:  2011-02-01 종목코드:  AMZN long 진입 가격:  120.07 long 청산 가격:  172.110001 return:  43.34
# 진입일:  2011-02-01 종목코드:  AAPL long 진입 가격:  43.179466
# 진입일:  2011-04-01 종목코드:  AMZN long 진입 가격:  180.130005
# 개별 청산일:  2011-04-01 종목코드:  AAPL long 진입 가격:  43.179466 long 청산 가격:  43.120655 return:  -0.14
# 개별 청산일:  2011-06-01 종목코드:  AMZN long 진입 가격:  180.130005 long 청산 가격:  192.399994 return:  6.81
# 진입일:  2011-06-01 종목코드:  BND long 진입 가격:  66.480408
# 진입일:  2011-07-01 종목코드:  AMZN long 진입 가격:  209.490005
# 개별 청산일:  2011-07-01 종목코드:  BND long 진입 가격:  66.480408 long 청산 가격:  65.942078 return:  -0.81
# 개별 청산일:  2011-08-01 종목코드:  AMZN long 진입 가격:  209.490005 long 청산 가격:  221.320007 return:  5.65
# 진입일:  2011-08-01 종목코드:  AAPL long 진입 가격:  49.652069
# 진입일:  2011-09-01 종목코드:  BND long 진입 가격:  68.38459
# 개별 청산일:  2011-09-01 종목코드:  AAPL long 진입 가격:  49.652069 long 청산 가격:  47.684769 return:  -3.96
# 진입일:  2011-10-03 종목코드:  AMZN long 진입 가격:  211.979996
# 개별 청산일:  2011-10-03 종목코드:  BND long 진입 가격:  68.38459 long 청산 가격:  68.937309 return:  0.81
# 개별 청산일:  2011-11-01 종목코드:  AMZN long 진입 가격:  211.979996 long 청산 가격:  212.100006 return:  0.06
# 진입일:  2011-11-01 종목코드:  AAPL long 진입 가격:  49.622044
# 진입일:  2011-12-01 종목코드:  BND long 진입 가격:  68.562042
# 개별 청산일:  2011-12-01 종목코드:  AAPL long 진입 가격:  49.622044 long 청산 가격:  48.548275 return:  -2.16
# 개별 청산일:  2012-01-03 종목코드:  BND long 진입 가격:  68.562042 long 청산 가격:  69.177887 return:  0.9
# 진입일:  2012-01-03 종목코드:  AAPL long 진입 가격:  51.464207
# 진입일:  2012-04-02 종목코드:  AMZN long 진입 가격:  198.050003
# 개별 청산일:  2012-04-02 종목코드:  AAPL long 진입 가격:  51.464207 long 청산 가격:  77.419693 return:  50.43
# 개별 청산일:  2012-06-01 종목코드:  AMZN long 진입 가격:  198.050003 long 청산 가격:  208.220001 return:  5.14
# 진입일:  2012-06-01 종목코드:  BND long 진입 가격:  71.178406
# 진입일:  2012-07-02 종목코드:  AMZN long 진입 가격:  229.320007
# 개별 청산일:  2012-07-02 종목코드:  BND long 진입 가격:  71.178406 long 청산 가격:  71.125717 return:  -0.07
# 개별 청산일:  2012-08-01 종목코드:  AMZN long 진입 가격:  229.320007 long 청산 가격:  232.089996 return:  1.21
# 진입일:  2012-08-01 종목코드:  AAPL long 진입 가격:  75.94046
# 진입일:  2012-10-01 종목코드:  AMZN long 진입 가격:  252.009995
# 개별 청산일:  2012-10-01 종목코드:  AAPL long 진입 가격:  75.94046 long 청산 가격:  82.874992 return:  9.13
# 개별 청산일:  2012-11-01 종목코드:  AMZN long 진입 가격:  252.009995 long 청산 가격:  232.139999 return:  -7.88
# 진입일:  2012-11-01 종목코드:  BND long 진입 가격:  71.913559
# 진입일:  2012-12-03 종목코드:  AMZN long 진입 가격:  250.330002
# 개별 청산일:  2012-12-03 종목코드:  BND long 진입 가격:  71.913559 long 청산 가격:  72.123268 return:  0.29
# 개별 청산일:  2013-03-01 종목코드:  AMZN long 진입 가격:  250.330002 long 청산 가격:  265.73999 return:  6.16
# 진입일:  2013-03-01 종목코드:  BND long 진입 가격:  71.360786
# 개별 청산일:  2013-04-01 종목코드:  BND long 진입 가격:  71.360786 long 청산 가격:  71.298386 return:  -0.09
# 진입일:  2013-04-01 종목코드:  AAPL long 진입 가격:  54.46909
# 진입일:  2013-06-03 종목코드:  AMZN long 진입 가격:  266.880005
# 개별 청산일:  2013-06-03 종목코드:  AAPL long 진입 가격:  54.46909 long 청산 가격:  57.617699 return:  5.78
# 개별 청산일:  2013-08-01 종목코드:  AMZN long 진입 가격:  266.880005 long 청산 가격:  305.570007 return:  14.5
# 진입일:  2013-08-01 종목코드:  AAPL long 진입 가격:  58.379593
# 진입일:  2013-10-01 종목코드:  AMZN long 진입 가격:  320.950012
# 개별 청산일:  2013-10-01 종목코드:  AAPL long 진입 가격:  58.379593 long 청산 가격:  62.790127 return:  7.55
# 개별 청산일:  2014-01-02 종목코드:  AMZN long 진입 가격:  320.950012 long 청산 가격:  397.970001 return:  24.0
# 진입일:  2014-01-02 종목코드:  AAPL long 진입 가격:  71.591667
# 진입일:  2014-02-03 종목코드:  BND long 진입 가격:  70.937912
# 개별 청산일:  2014-02-03 종목코드:  AAPL long 진입 가격:  71.591667 long 청산 가격:  64.913078 return:  -9.33
# 개별 청산일:  2014-03-03 종목코드:  BND long 진입 가격:  70.937912 long 청산 가격:  71.192856 return:  0.36
# 진입일:  2014-03-03 종목코드:  AAPL long 진입 가격:  68.716904
# 진입일:  2014-07-01 종목코드:  AMZN long 진입 가격:  332.390015
# 개별 청산일:  2014-07-01 종목코드:  AAPL long 진입 가격:  68.716904 long 청산 가격:  85.713371 return:  24.73
# 개별 청산일:  2014-08-01 종목코드:  AMZN long 진입 가격:  332.390015 long 청산 가격:  307.059998 return:  -7.62
# 진입일:  2014-08-01 종목코드:  AAPL long 진입 가격:  88.105499
# 진입일:  2014-09-02 종목코드:  AMZN long 진입 가격:  342.380005
# 개별 청산일:  2014-09-02 종목코드:  AAPL long 진입 가격:  88.105499 long 청산 가격:  95.147903 return:  7.99
# 개별 청산일:  2014-10-01 종목코드:  AMZN long 진입 가격:  342.380005 long 청산 가격:  317.459991 return:  -7.28
# 진입일:  2014-10-01 종목코드:  BND long 진입 가격:  72.65773
# 개별 청산일:  2014-11-03 종목코드:  BND long 진입 가격:  72.65773 long 청산 가격:  72.836952 return:  0.25
# 진입일:  2014-11-03 종목코드:  AAPL long 진입 가격:  100.766525
# 진입일:  2014-12-01 종목코드:  AMZN long 진입 가격:  326.0
# 개별 청산일:  2014-12-01 종목코드:  AAPL long 진입 가격:  100.766525 long 청산 가격:  106.448647 return:  5.64
# 개별 청산일:  2015-01-02 종목코드:  AMZN long 진입 가격:  326.0 long 청산 가격:  308.519989 return:  -5.36
# 진입일:  2015-01-02 종목코드:  BND long 진입 가격:  73.617195
# 진입일:  2015-02-02 종목코드:  AMZN long 진입 가격:  364.470001
# 개별 청산일:  2015-02-02 종목코드:  BND long 진입 가격:  73.617195 long 청산 가격:  75.042259 return:  1.94
# 개별 청산일:  2015-03-02 종목코드:  AMZN long 진입 가격:  364.470001 long 청산 가격:  385.660004 return:  5.81
# 진입일:  2015-03-02 종목코드:  AAPL long 진입 가격:  119.889519
# 진입일:  2015-04-01 종목코드:  BND long 진입 가격:  74.701561
# 개별 청산일:  2015-04-01 종목코드:  AAPL long 진입 가격:  119.889519 long 청산 가격:  115.394478 return:  -3.75
# 진입일:  2015-05-01 종목코드:  AMZN long 진입 가격:  422.869995
# 개별 청산일:  2015-05-01 종목코드:  BND long 진입 가격:  74.701561 long 청산 가격:  73.93969 return:  -1.02
# 개별 청산일:  2015-09-01 종목코드:  AMZN long 진입 가격:  422.869995 long 청산 가격:  496.540009 return:  17.42
# 진입일:  2015-09-01 종목코드:  BND long 진입 가격:  73.615601
# 진입일:  2015-10-01 종목코드:  AMZN long 진입 가격:  520.719971
# 개별 청산일:  2015-10-01 종목코드:  BND long 진입 가격:  73.615601 long 청산 가격:  74.071289 return:  0.62
# 개별 청산일:  2016-02-01 종목코드:  AMZN long 진입 가격:  520.719971 long 청산 가격:  574.809998 return:  10.39
# 진입일:  2016-02-01 종목코드:  BND long 진입 가격:  74.202827
# 개별 청산일:  2016-04-01 종목코드:  BND long 진입 가격:  74.202827 long 청산 가격:  75.734627 return:  2.06
# 진입일:  2016-04-01 종목코드:  AAPL long 진입 가격:  104.044418
# 진입일:  2016-05-02 종목코드:  AMZN long 진입 가격:  683.849976
# 개별 청산일:  2016-05-02 종목코드:  AAPL long 진입 가격:  104.044418 long 청산 가격:  88.578232 return:  -14.86
# 개별 청산일:  2016-06-01 종목코드:  AMZN long 진입 가격:  683.849976 long 청산 가격:  719.440002 return:  5.2
# 진입일:  2016-06-01 종목코드:  AAPL long 진입 가격:  93.704742
# 진입일:  2016-07-01 종목코드:  BND long 진입 가격:  77.698959
# 개별 청산일:  2016-07-01 종목코드:  AAPL long 진입 가격:  93.704742 long 청산 가격:  91.258865 return:  -2.61
# 개별 청산일:  2016-08-01 종목코드:  BND long 진입 가격:  77.698959 long 청산 가격:  77.703514 return:  0.01
# 진입일:  2016-08-01 종목코드:  AAPL long 진입 가격:  100.928177
# 진입일:  2016-10-03 종목코드:  AMZN long 진입 가격:  836.73999
# 개별 청산일:  2016-10-03 종목코드:  AAPL long 진입 가격:  100.928177 long 청산 가격:  107.66581 return:  6.68
# 개별 청산일:  2016-11-01 종목코드:  AMZN long 진입 가격:  836.73999 long 청산 가격:  785.409973 return:  -6.13
# 진입일:  2016-11-01 종목코드:  AAPL long 진입 가격:  106.680237
# 진입일:  2017-02-01 종목코드:  AMZN long 진입 가격:  832.349976
# 개별 청산일:  2017-02-01 종목코드:  AAPL long 진입 가격:  106.680237 long 청산 가격:  123.828148 return:  16.07
# 개별 청산일:  2017-03-01 종목코드:  AMZN long 진입 가격:  832.349976 long 청산 가격:  853.080017 return:  2.49
# 진입일:  2017-03-01 종목코드:  AAPL long 진입 가격:  135.028976
# 진입일:  2017-04-03 종목코드:  AMZN long 진입 가격:  891.51001
# 개별 청산일:  2017-04-03 종목코드:  AAPL long 진입 가격:  135.028976 long 청산 가격:  138.805832 return:  2.8
# 개별 청산일:  2017-07-03 종목코드:  AMZN long 진입 가격:  891.51001 long 청산 가격:  953.659973 return:  6.97
# 진입일:  2017-07-03 종목코드:  BND long 진입 가격:  76.933464
# 개별 청산일:  2017-08-01 종목코드:  BND long 진입 가격:  76.933464 long 청산 가격:  77.710747 return:  1.01
# 진입일:  2017-08-01 종목코드:  AAPL long 진입 가격:  145.537842
# 진입일:  2017-10-02 종목코드:  BND long 진입 가격:  77.825485
# 개별 청산일:  2017-10-02 종목코드:  AAPL long 진입 가격:  145.537842 long 청산 가격:  149.770599 return:  2.91
# 진입일:  2017-11-01 종목코드:  AMZN long 진입 가격:  1103.680054
# 개별 청산일:  2017-11-01 종목코드:  BND long 진입 가격:  77.825485 long 청산 가격:  77.885567 return:  0.08
# 개별 청산일:  2018-04-02 종목코드:  AMZN long 진입 가격:  1103.680054 long 청산 가격:  1371.98999 return:  24.31
# 진입일:  2018-04-02 종목코드:  BND long 진입 가격:  76.91954
# 진입일:  2018-05-01 종목코드:  AMZN long 진입 가격:  1582.26001
# 개별 청산일:  2018-05-01 종목코드:  BND long 진입 가격:  76.91954 long 청산 가격:  76.155106 return:  -0.99
# 개별 청산일:  2018-06-01 종목코드:  AMZN long 진입 가격:  1582.26001 long 청산 가격:  1641.540039 return:  3.75
# 진입일:  2018-06-01 종목코드:  AAPL long 진입 가격:  187.387604
# 진입일:  2018-07-02 종목코드:  AMZN long 진입 가격:  1713.780029
# 개별 청산일:  2018-07-02 종목코드:  AAPL long 진입 가격:  187.387604 long 청산 가격:  184.373459 return:  -1.61
# 개별 청산일:  2018-09-04 종목코드:  AMZN long 진입 가격:  1713.780029 long 청산 가격:  2039.51001 return:  19.01
# 진입일:  2018-09-04 종목코드:  AAPL long 진입 가격:  225.724899
# 진입일:  2018-10-01 종목코드:  BND long 진입 가격:  76.678947
# 개별 청산일:  2018-10-01 종목코드:  AAPL long 진입 가격:  225.724899 long 청산 가격:  224.637604 return:  -0.48
# 진입일:  2018-12-03 종목코드:  AMZN long 진입 가격:  1772.359985
# 개별 청산일:  2018-12-03 종목코드:  BND long 진입 가격:  76.678947 long 청산 가격:  76.764893 return:  0.11
# 개별 청산일:  2019-01-02 종목코드:  AMZN long 진입 가격:  1772.359985 long 청산 가격:  1539.130005 return:  -13.16
# 진입일:  2019-01-02 종목코드:  BND long 진입 가격:  78.239258
# 진입일:  2019-02-01 종목코드:  AMZN long 진입 가격:  1626.22998
# 개별 청산일:  2019-02-01 종목코드:  BND long 진입 가격:  78.239258 long 청산 가격:  78.729599 return:  0.63
# 개별 청산일:  2019-03-01 종목코드:  AMZN long 진입 가격:  1626.22998 long 청산 가격:  1671.72998 return:  2.8
# 진입일:  2019-03-01 종목코드:  AAPL long 진입 가격:  174.298782
# 진입일:  2019-05-01 종목코드:  AMZN long 진입 가격:  1911.52002
# 개별 청산일:  2019-05-01 종목코드:  AAPL long 진입 가격:  174.298782 long 청산 가격:  209.712402 return:  20.32
# 개별 청산일:  2019-06-03 종목코드:  AMZN long 진입 가격:  1911.52002 long 청산 가격:  1692.689941 return:  -11.45
# 진입일:  2019-06-03 종목코드:  BND long 진입 가격:  82.087845
# 누적 청산일:  2010-03-01 청산 종목 수:  1 청산 수익률:  0.005 누적 수익률:  1.005
# 누적 청산일:  2010-06-01 청산 종목 수:  1 청산 수익률:  0.248 누적 수익률:  1.2543
# 누적 청산일:  2010-08-02 청산 종목 수:  1 청산 수익률:  0.0222 누적 수익률:  1.2821
# 누적 청산일:  2011-02-01 청산 종목 수:  1 청산 수익률:  0.4334 누적 수익률:  1.8378
# 누적 청산일:  2011-04-01 청산 종목 수:  1 청산 수익률:  -0.0014 누적 수익률:  1.8353
# 누적 청산일:  2011-06-01 청산 종목 수:  1 청산 수익률:  0.0681 누적 수익률:  1.9603
# 누적 청산일:  2011-07-01 청산 종목 수:  1 청산 수익률:  -0.0081 누적 수익률:  1.9444
# 누적 청산일:  2011-08-01 청산 종목 수:  1 청산 수익률:  0.0565 누적 수익률:  2.0542
# 누적 청산일:  2011-09-01 청산 종목 수:  1 청산 수익률:  -0.0396 누적 수익률:  1.9728
# 누적 청산일:  2011-10-03 청산 종목 수:  1 청산 수익률:  0.0081 누적 수익률:  1.9888
# 누적 청산일:  2011-11-01 청산 종목 수:  1 청산 수익률:  0.0006 누적 수익률:  1.9899
# 누적 청산일:  2011-12-01 청산 종목 수:  1 청산 수익률:  -0.0216 누적 수익률:  1.9469
# 누적 청산일:  2012-01-03 청산 종목 수:  1 청산 수익률:  0.009 누적 수익률:  1.9643
# 누적 청산일:  2012-04-02 청산 종목 수:  1 청산 수익률:  0.5043 누적 수익률:  2.955
# 누적 청산일:  2012-06-01 청산 종목 수:  1 청산 수익률:  0.0514 누적 수익률:  3.1068
# 누적 청산일:  2012-07-02 청산 종목 수:  1 청산 수익률:  -0.0007 누적 수익률:  3.1045
# 누적 청산일:  2012-08-01 청산 종목 수:  1 청산 수익률:  0.0121 누적 수익률:  3.142
# 누적 청산일:  2012-10-01 청산 종목 수:  1 청산 수익률:  0.0913 누적 수익률:  3.4289
# 누적 청산일:  2012-11-01 청산 종목 수:  1 청산 수익률:  -0.0788 누적 수익률:  3.1585
# 누적 청산일:  2012-12-03 청산 종목 수:  1 청산 수익률:  0.0029 누적 수익률:  3.1678
# 누적 청산일:  2013-03-01 청산 종목 수:  1 청산 수익률:  0.0616 누적 수익률:  3.3628
# 누적 청산일:  2013-04-01 청산 종목 수:  1 청산 수익률:  -0.0009 누적 수익률:  3.3598
# 누적 청산일:  2013-06-03 청산 종목 수:  1 청산 수익률:  0.0578 누적 수익률:  3.554
# 누적 청산일:  2013-08-01 청산 종목 수:  1 청산 수익률:  0.145 누적 수익률:  4.0693
# 누적 청산일:  2013-10-01 청산 종목 수:  1 청산 수익률:  0.0755 누적 수익률:  4.3767
# 누적 청산일:  2014-01-02 청산 종목 수:  1 청산 수익률:  0.24 누적 수익률:  5.427
# 누적 청산일:  2014-02-03 청산 종목 수:  1 청산 수익률:  -0.0933 누적 수익률:  4.9207
# 누적 청산일:  2014-03-03 청산 종목 수:  1 청산 수익률:  0.0036 누적 수익률:  4.9384
# 누적 청산일:  2014-07-01 청산 종목 수:  1 청산 수익률:  0.2473 누적 수익률:  6.1599
# 누적 청산일:  2014-08-01 청산 종목 수:  1 청산 수익률:  -0.0762 누적 수익률:  5.6905
# 누적 청산일:  2014-09-02 청산 종목 수:  1 청산 수익률:  0.0799 누적 수익률:  6.1453
# 누적 청산일:  2014-10-01 청산 종목 수:  1 청산 수익률:  -0.0728 누적 수익률:  5.698
# 누적 청산일:  2014-11-03 청산 종목 수:  1 청산 수익률:  0.0025 누적 수익률:  5.7121
# 누적 청산일:  2014-12-01 청산 종목 수:  1 청산 수익률:  0.0564 누적 수익률:  6.0342
# 누적 청산일:  2015-01-02 청산 종목 수:  1 청산 수익률:  -0.0536 누적 수익률:  5.7106
# 누적 청산일:  2015-02-02 청산 종목 수:  1 청산 수익률:  0.0194 누적 수익률:  5.8212
# 누적 청산일:  2015-03-02 청산 종목 수:  1 청산 수익률:  0.0581 누적 수익률:  6.1596
# 누적 청산일:  2015-04-01 청산 종목 수:  1 청산 수익률:  -0.0375 누적 수익률:  5.9287
# 누적 청산일:  2015-05-01 청산 종목 수:  1 청산 수익률:  -0.0102 누적 수익률:  5.8682
# 누적 청산일:  2015-09-01 청산 종목 수:  1 청산 수익률:  0.1742 누적 수익률:  6.8905
# 누적 청산일:  2015-10-01 청산 종목 수:  1 청산 수익률:  0.0062 누적 수익률:  6.9332
# 누적 청산일:  2016-02-01 청산 종목 수:  1 청산 수익률:  0.1039 누적 수익률:  7.6534
# 누적 청산일:  2016-04-01 청산 종목 수:  1 청산 수익률:  0.0206 누적 수익률:  7.8113
# 누적 청산일:  2016-05-02 청산 종목 수:  1 청산 수익률:  -0.1486 누적 수익률:  6.6502
# 누적 청산일:  2016-06-01 청산 종목 수:  1 청산 수익률:  0.052 누적 수익률:  6.9963
# 누적 청산일:  2016-07-01 청산 종목 수:  1 청산 수익률:  -0.0261 누적 수익률:  6.8137
# 누적 청산일:  2016-08-01 청산 종목 수:  1 청산 수익률:  0.0001 누적 수익률:  6.8141
# 누적 청산일:  2016-10-03 청산 종목 수:  1 청산 수익률:  0.0668 누적 수익률:  7.269
# 누적 청산일:  2016-11-01 청산 종목 수:  1 청산 수익률:  -0.0613 누적 수익률:  6.823
# 누적 청산일:  2017-02-01 청산 종목 수:  1 청산 수익률:  0.1607 누적 수익률:  7.9198
# 누적 청산일:  2017-03-01 청산 종목 수:  1 청산 수익률:  0.0249 누적 수익률:  8.117
# 누적 청산일:  2017-04-03 청산 종목 수:  1 청산 수익률:  0.028 누적 수익률:  8.3441
# 누적 청산일:  2017-07-03 청산 종목 수:  1 청산 수익률:  0.0697 누적 수익률:  8.9258
# 누적 청산일:  2017-08-01 청산 종목 수:  1 청산 수익률:  0.0101 누적 수익률:  9.0159
# 누적 청산일:  2017-10-02 청산 종목 수:  1 청산 수익률:  0.0291 누적 수익률:  9.2782
# 누적 청산일:  2017-11-01 청산 종목 수:  1 청산 수익률:  0.0008 누적 수익률:  9.2853
# 누적 청산일:  2018-04-02 청산 종목 수:  1 청산 수익률:  0.2431 누적 수익률:  11.5426
# 누적 청산일:  2018-05-01 청산 종목 수:  1 청산 수익률:  -0.0099 누적 수익률:  11.4279
# 누적 청산일:  2018-06-01 청산 종목 수:  1 청산 수익률:  0.0375 누적 수익률:  11.8561
# 누적 청산일:  2018-07-02 청산 종목 수:  1 청산 수익률:  -0.0161 누적 수익률:  11.6654
# 누적 청산일:  2018-09-04 청산 종목 수:  1 청산 수익률:  0.1901 누적 수익률:  13.8825
# 누적 청산일:  2018-10-01 청산 종목 수:  1 청산 수익률:  -0.0048 누적 수익률:  13.8157
# 누적 청산일:  2018-12-03 청산 종목 수:  1 청산 수익률:  0.0011 누적 수익률:  13.8312
# 누적 청산일:  2019-01-02 청산 종목 수:  1 청산 수익률:  -0.1316 누적 수익률:  12.0111
# 누적 청산일:  2019-02-01 청산 종목 수:  1 청산 수익률:  0.0063 누적 수익률:  12.0863
# 누적 청산일:  2019-03-01 청산 종목 수:  1 청산 수익률:  0.028 누적 수익률:  12.4245
# 누적 청산일:  2019-05-01 청산 종목 수:  1 청산 수익률:  0.2032 누적 수익률:  14.9489
# 누적 청산일:  2019-06-03 청산 종목 수:  1 청산 수익률:  -0.1145 누적 수익률:  13.2376
# 누적 수익률:  13.2376
# /var/folders/6r/gdx2hrhn12n6q2bn8xfrvmwc0000gn/T/ipykernel_3998/2666238365.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book.loc[i, 'acc_rtn'] = acc_rtn
